# %% [markdown]
# <a href="https://colab.research.google.com/github/Briankimany/OBJECT-DETECTION/blob/main/Circuit/circuit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Briankimany/OBJECT-DETECTION.git
# Out:
# Cloning into 'OBJECT-DETECTION'...
# remote: Enumerating objects: 68, done.
# remote: Counting objects: 100% (68/68), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 68 (delta 18), reused 44 (delta 10), pack-reused 0
# Receiving objects: 100% (68/68), 25.10 MiB | 21.49 MiB/s, done.
# Resolving deltas: 100% (18/18), done.

# %%
! pip install git+https://github.com/Briankimany/enrypter_decrypter.git@main#egg=cyber
# Out:
# ...
#   Cloning https://github.com/Briankimany/enrypter_decrypter.git (to revision main) to /tmp/pip-install-9ys6v_wb/cyber_150047c17ce341de9f0d1064c4dd6071
#   Running command git clone --filter=blob:none --quiet https://github.com/Briankimany/enrypter_decrypter.git /tmp/pip-install-9ys6v_wb/cyber_150047c17ce341de9f0d1064c4dd6071
#   Resolved https://github.com/Briankimany/enrypter_decrypter.git to commit 895483961dd7042e3370152b9df85acce56b9f03
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for cyber: filename=cyber-0.2-py3-none-any.whl size=10904 sha256=760b0fb33e67946a6e01df00f0c26d3dca9c2233dfd752baf889e7721cc7fa39
#   Stored in directory: /tmp/pip-ephem-wheel-cache-fj51giik/wheels/cf/49/5f/254ebaba7e118d540651f12e9f6dcef0d465cc5e7183c2a071
# Successfully built cyber
# ...

# %%
import os
os.chdir("/content/OBJECT-DETECTION/Circuit")

# %%
# %ls
# Out:
# best.pt                    circuit_elements.py  dict.json  __pycache__/  utils2.py  YOLORESULTS/
# circuit_creation_utils.py  circuit.py           Images/    README.md     utils.py   yolovc.py

# %%
from circuit import Circuit
from circuit_elements import Element
from circuit_creation_utils import  use_get_cordinates , grab_new_data_structure

# %%
final_dict = grab_new_data_structure()
drawn_data = use_get_cordinates(final_dict , dest_folder = "/content/OBJECT-DETECTION/Circuit/Schematics")
v = {}
for i in list(drawn_data.items()):
  circuit_name , details  = i
  det ,lines, = details
  curr_circuit = Circuit(det , circuit_name)
  v[circuit_name] = curr_circuit , lines
# Out:
# (3, 320, 320, 3)

# %%
for p in v:
  circuit , file_lines = v[p]
  circuit.get_juntions()
  b = circuit.split_circuit()
# Out:
# we have reached the end
# not top r_1
# not top r_3
# at teh top r_4 290.0007862214688 60.00087863028662
#
#
#
#
#
#
# [<circuit_elements.Element object at 0x7b372cbd21d0>, <circuit_elements.Element object at 0x7b372cbd1810>, <circuit_elements.Element object at 0x7b372cbd2290>, <circuit_elements.Element object at 0x7b372cbd1fc0>, <circuit_elements.Element object at 0x7b372cbd3dc0>, <circuit_elements.Element object at 0x7b372cbd3700>]
# we have reached the end
# not top r_1
# not top r_2
# at teh top r_3 290.0009316325068 110.00045010127279
# at teh top c_1 290.0009316325068 110.00045010127279
#
#
#
#
#
#
# [<circuit_elements.Element object at 0x7b372cbd2b90>, <circuit_elements.Element object at 0x7b372cbd2ad0>, <circuit_elements.Element object at 0x7b372cbd26e0>, <circuit_elements.Element object at 0x7b372cbd2c80>, <circuit_elements.Element object at 0x7b372cbd2a70>, <circuit_elements.Element object at 0x7b372cbd25f0>, <circuit_elements.Element object at 0x7b372cbd3f10>]
# []

# %%
circuit_ = v['10'][0]
print(circuit_.sub_circuit_dict)
for i in circuit_.sub_circuit_dict:
  print(i)
# Out:
# {}

# %%
print(b)
# Out:
# None
